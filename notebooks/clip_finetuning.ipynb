# %% [markdown]
# # GeoAI CLIP Fine-Tuning Walkthrough
#
# Use `backend/model/train.py` as the main training entry point. This notebook is a lightweight placeholder for experiment notes, charts, and screenshots once you start running Country211 training jobs.

# %%
from backend.model.train import train_classifier

# train_classifier(Path('./artifacts/country211'))
